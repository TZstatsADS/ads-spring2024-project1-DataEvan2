# %% [markdown]
# ## A Story about Married Men

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
image_path = 'age_distribution.png'
img = Image.open(image_path)
plt.figure(figsize=(10, 8)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# Since the majority of people responded are from USA and are within 20-40 year old, the analysis is mostly focused on people within this demographic.
#
# In the vast and diverse landscape of human emotions and experiences, the HappyDB dataset, a large-scale collection of happy moments, provides a unique window into the lives of people, particularly those in the United States aged between 20 and 40. This story, grounded in data and narrated with a touch of human insight, paints a vivid picture of how marital status and gender intersect with happiness and life's milestones.

# %% [markdown]
# ## What is the performance of married men versus single men in the workplace?

# %%
image_path = 'top_words_married24.png'
img = Image.open(image_path)
plt.figure(figsize=(8,6)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'top_words_married3m.png'
img = Image.open(image_path)
plt.figure(figsize=(8,6)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'topic_comparison_affec.png'
img = Image.open(image_path)
plt.figure(figsize=(8,6)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'category_gender_marital.png'
img = Image.open(image_path)
plt.figure(figsize=(15,12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# Single men, it seems, frequently talk about their bosses. This could point to a stage in their careers where they're perhaps more focused on navigating workplace dynamics and hierarchies. Interestingly, they don't mention their achievements as much. This might suggest that they're either at an earlier stage in their careers, where significant milestones are yet to be achieved, or perhaps they place less emphasis on broadcasting these achievements.
#
# On the other hand, married men seem to have a different focus. They talk less about their bosses and more about promotions and career advancements. This shift in conversation topics could be a marker of having reached a certain level of career stability and achievement. It aligns with a common societal narrative where individuals often decide to marry and start families when they feel established in their careers, financially secure, and able to support a family.
#
# The less frequent mention of bosses by married men could indicate a transition from being closely managed to perhaps taking on more autonomous, higher-level roles. Their increased mentions of promotions and career achievements might reflect a sense of pride and fulfillment in their professional lives, which they are eager to share.
#
# These trends point to a broader societal narrative: single men are often still climbing the career ladder, while married men are more likely to have reached a level of professional achievement that aligns with traditional expectations of family and financial readiness. However, it's crucial to acknowledge that these are general trends and individual experiences may vary greatly.

# %% [markdown]
# Quotes from Married Men:
#
# "I received a bonus yesterday from my work here in mturk which is really nice."
#
# "I received an award for my work on a tough loan process that I helped develop."
#
# "I secured funding for a project at work that will boost loan sales by at least 60%."

# %% [markdown]
# Quotes from Single Men:
#
# "Won a raffle at work for 6 months of Graze, and I love mystery boxes! "
#
# "I got acknowledged by my manager for my hard work I've been putting in recently. "
#
# "I got a compliment from my manager at work the other day."

# %% [markdown]
# Based on these quota, for married males, their professional achievements are not just personal triumphs but milestones with substantial impact and strategic value. Consider the words of married men who spoke of receiving a significant bonus for his contributions, or another who was recognized for his role in developing a complex loan process. Yet another shared his success in securing funding for a project, potentially boosting sales by a remarkable 60%. These stories are not just about personal gratification; they reflect a deep sense of fulfillment derived from making meaningful contributions to their organizations. The scale and scope of their achievements suggest a stage in life where long-term planning, strategic thinking, and a focus on impactful outcomes define their professional identity.
#
# In contrast, the narratives of single males in the workplace paint a different picture. Their moments of happiness are rooted in personal recognition and immediate gratification. Winning a raffle, receiving acknowledgment from a manager for hard work, or a compliment on recent efforts – these are the moments that bring them joy. While these achievements might seem modest compared to those of their married counterparts, they are no less significant. They represent a career stage where immediate recognition, personal growth, and the enjoyment of momentary rewards are central to their professional satisfaction.

# %%
image_path = 'top_wordcloud.png'
img = Image.open(image_path)
plt.figure(figsize=(10,8)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ## What do men do outside of work?

# %%
image_path = 'category_gender_marital.png'
img = Image.open(image_path)
plt.figure(figsize=(15,12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'total_male_topic.png'
img = Image.open(image_path)
plt.figure(figsize=(15,12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'married_male_topic.png'
img = Image.open(image_path)
plt.figure(figsize=(15,12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'topic_comparison_moment.png'
img = Image.open(image_path)
plt.figure(figsize=(10,8)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'topic_comparison_bonding.png'
img = Image.open(image_path)
plt.figure(figsize=(10,8)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The insights from the HappyDB dataset offer a fascinating peek into the lives of different people outside of work.
#
# First off, married men seem to focus a lot on their families. Words like 'wife,' 'son,' and 'daughter' pop up often in their conversations. This suggests that for these men, family is a big deal and occupies a central place in their lives. Interestingly, these married guys don't talk about food as much as single men do. One reason might be that in many families, the wife often takes care of meal-related matters, a setup that reflects traditional roles still present in some households.
#
# As for affection, it turns out that married and single men are on the same page; both groups express affection similarly. This challenges the stereotype that marriage might dampen a man's emotional expression. On the other hand, married women seem to show more affection compared to single women. This could mean that being in a marriage might create more opportunities or a comfortable space for women to express affection.
#
# Married men seem to have less time for entertainment compared to their single counterparts. This observation aligns well with traditional societal roles, where married men often bear more responsibilities, particularly those related to family, which could limit their leisure time.
#
# This trend suggests a shift in priorities that typically accompanies marriage. For many married men, time once spent on personal entertainment may now be redirected towards family activities or responsibilities. It reflects a broader societal expectation where, upon entering marriage, men are often anticipated to adopt more family-centric roles, possibly at the expense of personal leisure pursuits.
#
# Furthermore, this could also indicate a change in the nature of leisure activities post-marriage. Married men might engage in different types of entertainment, perhaps those that are more family-oriented or home-based, as opposed to the more individualistic and outgoing activities that might characterize single life.
#
# These observations are more than just interesting facts; they shed light on bigger social and cultural patterns. They show us how marriage and single life can shape the way people talk and express themselves. It's not just about whether someone is married or not; it's also about the roles, responsibilities, and expectations that come with these life choices.

# %% [markdown]
# ## Question: How large is the emotional support for married men?

# %%
image_path = 'male_female_valency.png'
img = Image.open(image_path)
plt.figure(figsize=(15, 12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'male_marital_arousal.png'
img = Image.open(image_path)
plt.figure(figsize=(15, 12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'male_marital_3m.png'
img = Image.open(image_path)
plt.figure(figsize=(15, 12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = 'male_marital_24h.png'
img = Image.open(image_path)
plt.figure(figsize=(15, 12)) 
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# The intriguing data from the HappyDB study reveals a rather heartwarming trend: married men, on average, seem to ride a higher wave of positive emotions and exhibit a stronger grip on their feelings than their single counterparts. This observation opens a window to some deeper societal reflections, especially in the context of emotional well-being and the role of relationships.
#
# At its core, this finding champions the emotional benefits of companionship that marriage often brings. It's as though having a life partner provides a secure emotional anchor, a kind of emotional safety net. Married men, buoyed by this support, might find themselves better equipped to face life's ups and downs with a more positive outlook and a firmer handle on their emotions.
#
# This leads us to ponder the broader societal implications, particularly about the support structures we have in place for those who are single. It's crucial to recognize that while marriage can offer emotional benefits, it's not the only path to happiness and emotional stability. The data shouldn't be seen as a one-size-fits-all, but rather as a prompt to acknowledge the diverse ways in which people find happiness and support.
#
# Moreover, this insight sheds light on the need for stronger emotional support systems for everyone, regardless of their marital status. Whether it's fostering deeper friendships, building supportive communities, or enhancing mental health resources, society benefits when each individual has access to emotional support and avenues for personal growth.
#
# In conclusion, the HappyDB dataset offers a fascinating glimpse into the mosaic of human happiness. For married males, their joy is often found in the intertwined realms of professional success and family life, marked by a sense of emotional stability and control. Single males, in contrast, find happiness in personal achievements and immediate pleasures like food and entertainment. Married females, with a focus on affection, highlight the emotional depth in their relationships. This story, drawn from the data, is a testament to the complex tapestry of human emotions and the varied paths to happiness in our lives.
